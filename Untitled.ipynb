# %%
from arc import *
import matplotlib.pyplot as plt

# %%
atom=Rubidium87()

# %%
3e8/atom.getTransitionFrequency(5,2,5/2,80,1,3/2)/1e-9
# Out:
# 1255.7361843528793

# %%
atom.getTransitionRate(80, 1, 1.5, 5, 2, 5/2, temperature=0.1)
# Out:
# 93.9644514154616

# %%
plt.plot(range(70,100),[3e8/atom.getTransitionFrequency(5,2,5/2,x,1,3/2)/1e-9 for x in range(70,100)])

# %%
plt.plot(range(70,100),[atom.getTransitionRate(x, 1, 1.5, 5, 2, 5/2, temperature=0.1) for x in range(70,100)])
plt.plot(range(80,110),[atom.getTransitionRate(x, 1, 1.5, 5, 2, 5/2, temperature=300) for x in range(80,110)])
